# %% [markdown]
# <a href="https://colab.research.google.com/github/cdkuea/456469ek-/blob/main/Maestr%C3%ADa_teor%C3%ADa_09_Multi_layer_perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/dieguito1331/cienciaDatos/blob/master/maestria/teoria/09 - Multi layer perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Perceptron multicapa
#
# ![imagen](https://i.ytimg.com/vi/Fz4Uo8_uUfg/hqdefault.jpg)

# %% [markdown]
# Los perceptrones multicapa posee como mínimo tres capas de neuronas:
# * La capa de entrada (la cantidad de neuronas dependerá de las variables de entrada)
# * Capa de salida (la cantidad de neuronas dependerá de la cantidad de salidas que vayamos a tener)
# * Capas ocultas: En las capas ocultas se realiza todo el procesamiento. A medida que agregamos más capas ocultas, la complejidad de la red aumenta.
#
# Si un perceptrón posee una única capa oculta, se llamará _shallow neural network_ (red neuronal poco profunda)
# Si un perceptrón posee más de una capa oculta se llamará _deep neural networks_ (redes neuronales profundas)
#
# Cada neurona poseerá un peso. Por tal motivo, las operaciones matemáticas que se generarán en la red será multiplicaciones matriciales.

# %% [markdown]
# Para poder trabajar con un perceptron multicapa se debe definir lo siguiente:
# * Cantidad de capas ocultas
# * Cantidad de neuronas por capa oculta
# * Función de activación
# * Función de pérdida
# * Algoritmo de backpropagation
#
# No siempre es mejor usar una red compleja. En general mientras más compleja sea la red, más tiempo tardará el proceso de entrenamiento y pueden surgir problemas de overfitting. Por otro lado, mientras menos compleja es una red menos capacidad tendrá de distinguir relaciones no lineales entre las entradas y las salidas.

# %% [markdown]
# **Definimos los pesos de la red neuronal**
#
# $$\mathbf{W} = \left[\begin{array}
# {rr}
# w_{1,1} & w_{1,2} \\
# w_{2,1} & w_{2,2}  \\
# w_{3,1} & w_{3,2}
# \end{array}\right]
# $$
#
# Cada una de las filas se relacionan con las entradas y las columnas con los nodos intermedios. Las entradas son del tipo:
#
# $$\mathbf{X} = \left[\begin{array}
# {rrr}
# x_{1} & x_{2} & x_{3}
# \end{array}\right]
# $$
#
#
# En nuestro ejemplo tendremos una matriz de 4x3 y una segunda matriz de 3x2

# %% [markdown]
# Una función de activación puede ser la **sigmoide**
# $$\sigma(x) = \frac{1}{1+e^{-x}}$$
#
# Otra función puede ser la función **ReLu** (Rectified Linear Units). Cualquier valor menor a 0 la función lo convierte en 0, sino el valor de entrada es el valor de salida.
#
# $$f(X) = max(0,X)$$

# %%
import os
from google.colab import drive
import pandas as pd
from sklearn.model_selection import train_test_split##
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
import pandas as pd

from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, roc_auc_score, roc_curve
from sklearn.neural_network import MLPClassifier



#Levanto drive para poder almacenar los archivos
drive.mount("/content/drive")
contentFolder = "/content/drive/MyDrive/Austral - Data Mining"
if not os.path.exists(contentFolder):
    os.mkdir(contentFolder)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv("{}/titanicPreprocesada.txt".format(contentFolder), sep=";")

# %%
#estandarizamos el dataset y lo convertimos en numpy array para usarlo en el modelo.
X = data.drop(columns = ["index", "Survived"])
y = data.Survived
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.33, random_state=42)
X_train = X_train.values.astype(np.float32, order="C") #order=c quiere decir que las operaciones por fila son mas rapidas q columnas (order = f)
X_test = X_test.values.astype(np.float32, order="C")
scaler = StandardScaler() 
X_train = scaler.fit_transform(X_train)#estandarizo los datos. z = (x - u) / s  
X_test = scaler.fit_transform(X_test)


Y_train = Y_train.values
Y_test = Y_test.values

# %% [markdown]
# ### Modelo hecho a mano

# %%
# Define the sigmoid activator; we ask if we want the sigmoid or its derivative
def sigmoid_act(x, der=False):
    import numpy as np
    
    if (der==True) : #derivative of the sigmoid
        f = 1/(1+ np.exp(- x))*(1-1/(1+ np.exp(- x)))
    else : # sigmoid
        f = 1/(1+ np.exp(- x))
    
    return f

# We may employ the Rectifier Linear Unit (ReLU)
def ReLU_act(x, der=False):
    import numpy as np
    
    if (der == True): # the derivative of the ReLU is the Heaviside Theta
        f = np.heaviside(x, 1)
    else :
        f = np.maximum(x, 0)
    
    return f

# %%
# Set up the number of perceptron per each layer:
p=4 # Layer 1
q=4 # Layer 2

# Set up the Learning rate
eta =  1/623


# 0: Random initialize the relevant data 
w1 = 2*np.random.rand(p , X_train.shape[1]) - 0.5  # Layer 1 
b1 = np.random.rand(p)

w2 = 2*np.random.rand(q , p) - 0.5  # Layer 2
b2 = np.random.rand(q)

wOut = 2*np.random.rand(q) - 0.5  # Output Layer
bOut = np.random.rand(1)

mu = [] #loss function for the passenger
vec_y = [] 

# Start looping over the passengers, i.e. over I.

for I in range(0, X_train.shape[0]): #loop in all the passengers entre 0 y 596
    
    # 1: input the data 
    x = X_train[I]
    
    
    # 2: Start the algorithm
    
    # 2.1: Feed forward
    z1 = ReLU_act(np.dot(w1, x) + b1) # output layer 1 np.dot realiza la multiplicacion entre 2 matrices
    z2 = ReLU_act(np.dot(w2, z1) + b2) # output layer 2
    y = sigmoid_act(np.dot(wOut, z2) + bOut) # Output of the Output layer
    
    #2.2: Compute the output layer's error
    delta_Out = 2*(y-Y_train[I]) * sigmoid_act(y, der=True)
    
    #2.3: Backpropagate
    delta_2 = delta_Out * wOut * ReLU_act(z2, der=True) # Second Layer Error
    delta_1 = np.dot(delta_2, w2) * ReLU_act(z1, der=True) # First Layer Error
    
    # 3: Gradient descent 
    wOut = wOut - eta*delta_Out*z2  # Outer Layer
    bOut = bOut - eta*delta_Out
    
    w2 = w2 - eta*np.kron(delta_2, z1).reshape(q,p) # Hidden Layer 2 np.kron es una multiplicacion kronecker entre dos matrices. matriz a de m*n y matriz b de p*q, se forma una matriz de mp*nq
    b2 = b2 - eta*delta_2
    
    w1 = w1 - eta*np.kron(delta_1, x).reshape(p, x.shape[0]) # Hidden Layer 1
    b1 = b1 - eta*delta_1
    
    # 4. Computation of the loss function
    mu.append((1/2)*(y-Y_train[I])**2)
    vec_y.append(y[0])

# %%
def ANN_train(X_train, Y_train, p=4, q=4, eta=0.0015): #Artificial Neural Network
    
    # 0: Random initialize the relevant data 
    w1 = 2*np.random.rand(p , X_train.shape[1]) - 0.5 # Layer 1
    b1 = np.random.rand(p)

    w2 = 2*np.random.rand(q , p) - 0.5  # Layer 2
    b2 = np.random.rand(q)

    wOut = 2*np.random.rand(q) - 0.5   # Output Layer
    bOut = np.random.rand(1)

    mu = []
    vec_y = []

    # Start looping over the passengers, i.e. over I.

    for I in range(0, X_train.shape[0]-1): #loop in all the passengers:
    
        # 1: input the data 
        x = X_train[I]
    
        # 2: Start the algorithm
    
        # 2.1: Feed forward
        z1 = ReLU_act(np.dot(w1, x) + b1) # output layer 1 
        z2 = ReLU_act(np.dot(w2, z1) + b2) # output layer 2
        y = sigmoid_act(np.dot(wOut, z2) + bOut) # Output of the Output layer
    
        #2.2: Compute the output layer's error
        delta_Out = 2 * (y-Y_train[I]) * sigmoid_act(y, der=True)
    
        #2.3: Backpropagate
        delta_2 = delta_Out * wOut * ReLU_act(z2, der=True) # Second Layer Error
        delta_1 = np.dot(delta_2, w2) * ReLU_act(z1, der=True) # First Layer Error
    
        # 3: Gradient descent 
        wOut = wOut - eta*delta_Out*z2  # Outer Layer
        bOut = bOut - eta*delta_Out
    
        w2 = w2 - eta*np.kron(delta_2, z1).reshape(q,p) # Hidden Layer 2
        b2 = b2 -  eta*delta_2
    
        w1 = w1 - eta*np.kron(delta_1, x).reshape(p, x.shape[0])
        b1 = b1 - eta*delta_1
    
        # 4. Computation of the loss function
        mu.append((y-Y_train[I])**2)
        vec_y.append(y)
    
    #calculo la perdida promedio por batch.  divido los outputs en 9 batches de 60 cada uno, sumo el output de la loss function y lo divido por 60.
    batch_loss = []
    for i in range(0, 9):
        loss_avg = 0
        for m in range(0, 59):
            loss_avg+=vec_y[60*i+m]/60
        batch_loss.append(loss_avg)
    
    
    plt.figure(figsize=(10,6))
    plt.scatter(np.arange(1, len(batch_loss)+1), batch_loss, alpha=1, s=10, label='error')
    plt.title('Average Loss by epoch', fontsize=20)
    plt.xlabel('Epoch', fontsize=16)
    plt.ylabel('Loss', fontsize=16)
    plt.show()
    
    return w1, b1, w2, b2, wOut, bOut, mu

# %%
w1, b1, w2, b2, wOut, bOut, mu = ANN_train(X_train, Y_train, p=8, q=4, eta=0.0015)

# %%
#aplico los parametros entrenados a la base de test.
def ANN_pred(X_test, w1, b1, w2, b2, wOut, bOut, mu):
    import numpy as np
    
    pred = []
    
    for I in range(0, X_test.shape[0]): #loop in all the passengers
        # 1: input the data 
        x = X_test[I]
        
        # 2.1: Feed forward
        z1 = ReLU_act(np.dot(w1, x) + b1) # output layer 1 
        z2 = ReLU_act(np.dot(w2, z1) + b2) # output layer 2
        y = sigmoid_act(np.dot(wOut, z2) + bOut)  # Output of the Output layer
        
        # Append the prediction;
        # We now need a binary classifier; we apply an Heaviside Theta and we set to 0.5 the threshold
        # if y < 0.5 the output is zero, otherwise is 1
        pred.append( np.heaviside(y - 0.5, 1)[0] )
    
    
    return np.array(pred)

# %%
#en vez de arrojar la prediccion, calcula la probabilidad

def ANN_pred_proba(X_test, w1, b1, w2, b2, wOut, bOut, mu):
    import numpy as np
    
    pred = []
    
    for I in range(0, X_test.shape[0]): #loop in all the passengers
        # 1: input the data 
        x = X_test[I]
        
        # 2.1: Feed forward
        z1 = ReLU_act(np.dot(w1, x) + b1) # output layer 1 
        z2 = ReLU_act(np.dot(w2, z1) + b2) # output layer 2
        y = sigmoid_act(np.dot(wOut, z2) + bOut)  # Output of the Output layer
        
        pred.append(y)
    
    
    return np.array(pred)

# %%
predictions = ANN_pred(X_test, w1, b1, w2, b2, wOut, bOut, mu)
preds = ANN_pred_proba(X_test, w1, b1, w2, b2, wOut, bOut, mu)

# %%
# Plot the confusion matrix
cm = confusion_matrix(Y_test, predictions)

plt.figure(figsize = (7,7))
sns.heatmap(cm, annot=True, cmap=plt.cm.Blues, fmt='g')
plt.xlabel("Predicted Class", fontsize=18)
plt.ylabel("True Class", fontsize=18)
plt.show()

# %%
#De esta forma graficamos la curva ROC y calculamos el área debajo de la curva
plt.figure(figsize=(10,10))
plt.title("Grafico ROC para el model")


areaBajoCurva = roc_auc_score(Y_test, preds)
fpr, tpr, _ = roc_curve(Y_test, preds)
plt.plot(fpr, tpr, label="{} - AUC:{}".format("red", round(areaBajoCurva,4)))


plt.legend(loc="lower right")
plt.plot([0,1])
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.show()

# %% [markdown]
# ### Modelo en scikit-learn

# %% [markdown]
# Vamos a crear un modelo un poco más complejo ya que agregaremos dos capas ocultas (Trabajaremos con deep learning)

# %%
#Initializing the MLPClassifier
classifier = MLPClassifier(hidden_layer_sizes=(16,12), max_iter=300,activation = 'relu',solver='adam',random_state=1) #adam es un optimizador
classifier.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(hidden_layer_sizes=(16, 12), max_iter=300, random_state=1)

# %%
y_pred = classifier.predict(X_test)
y_probas = classifier.predict_proba(X_test)[:,-1]

# %%
accuracy_score(Y_test, y_pred)
# Out:
# 0.8101694915254237

# %%
#De esta forma graficamos la curva ROC y calculamos el área debajo de la curva
plt.figure(figsize=(10,10))
plt.title("Grafico ROC para el model")


areaBajoCurva = roc_auc_score(Y_test, y_probas)
fpr, tpr, _ = roc_curve(Y_test, y_probas)
plt.plot(fpr, tpr, label="{} - AUC:{}".format("red", round(areaBajoCurva,4)))


plt.legend(loc="lower right")
plt.plot([0,1])
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.show()

# %% [markdown]
# ### Modelo en Keras

# %%
#Dependencies.  Keras es una libreria de deep learning.  
import keras
from keras.models import Sequential
from keras.layers import Dense
# Neural network
model = Sequential()
model.add(Dense(16, input_dim=9, activation='relu')) #capa de entrada con 9 perceptrones, la primera capa oculta tiene 16.
model.add(Dense(12, activation='relu')) #la segunda capa oculta tiene 12
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['AUC']) #compile especifica el proceso de aprendizaje de una red.

# %%
history = model.fit(X_train, Y_train, epochs=100) #training performance of the model
# Out:
# Epoch 1/100
# 19/19 [==============================] - 1s 3ms/step - loss: 0.6816 - auc: 0.5808
# Epoch 2/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6437 - auc: 0.7322
# Epoch 3/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6123 - auc: 0.7915
# Epoch 4/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5839 - auc: 0.8145
# Epoch 5/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5584 - auc: 0.8218
# Epoch 6/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5364 - auc: 0.8229
# Epoch 7/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5174 - auc: 0.8302
# Epoch 8/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.5033 - auc: 0.8319
# Epoch 9/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4929 - auc: 0.8279
# Epoch 10/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4840 - auc: 0.8370
# Epoch 11/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4771 - auc: 0.8410
# Epoch 12/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4726 - auc: 0.8398
# Epoch 13/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.4670 - auc: 0.8439
# Epoch 14/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.4631 - auc: 0.8461
# Epoch 15/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4603 - auc: 0.8466
# Epoch 16/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4562 - auc: 0.8503
# Epoch 17/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4530 - auc: 0.8502
# Epoch 18/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4494 - auc: 0.8541
# Epoch 19/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4463 - auc: 0.8552
# Epoch 20/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4435 - auc: 0.8575
# Epoch 21/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4399 - auc: 0.8594
# Epoch 22/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4371 - auc: 0.8614
# Epoch 23/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4336 - auc: 0.8645
# Epoch 24/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4308 - auc: 0.8667
# Epoch 25/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4280 - auc: 0.8698
# Epoch 26/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4255 - auc: 0.8708
# Epoch 27/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4230 - auc: 0.8720
# Epoch 28/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4202 - auc: 0.8735
# Epoch 29/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4177 - auc: 0.8748
# Epoch 30/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4151 - auc: 0.8766
# Epoch 31/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4131 - auc: 0.8782
# Epoch 32/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4109 - auc: 0.8779
# Epoch 33/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.4090 - auc: 0.8797
# Epoch 34/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.4077 - auc: 0.8799
# Epoch 35/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4059 - auc: 0.8812
# Epoch 36/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4050 - auc: 0.8820
# Epoch 37/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4034 - auc: 0.8819
# Epoch 38/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4020 - auc: 0.8824
# Epoch 39/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.4015 - auc: 0.8832
# Epoch 40/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3992 - auc: 0.8847
# Epoch 41/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3978 - auc: 0.8855
# Epoch 42/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3979 - auc: 0.8842
# Epoch 43/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3960 - auc: 0.8855
# Epoch 44/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3954 - auc: 0.8865
# Epoch 45/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3944 - auc: 0.8864
# Epoch 46/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3942 - auc: 0.8871
# Epoch 47/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3921 - auc: 0.8879
# Epoch 48/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3915 - auc: 0.8885
# Epoch 49/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3902 - auc: 0.8897
# Epoch 50/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3904 - auc: 0.8881
# Epoch 51/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3898 - auc: 0.8904
# Epoch 52/100
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3884 - auc: 0.8893
# Epoch 53/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3878 - auc: 0.8887
# Epoch 54/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3874 - auc: 0.8908
# Epoch 55/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3890 - auc: 0.8885
# Epoch 56/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3857 - auc: 0.8923
# Epoch 57/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3867 - auc: 0.8908
# Epoch 58/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3842 - auc: 0.8920
# Epoch 59/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3836 - auc: 0.8914
# Epoch 60/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3834 - auc: 0.8916
# Epoch 61/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3825 - auc: 0.8927
# Epoch 62/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3814 - auc: 0.8940
# Epoch 63/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3819 - auc: 0.8926
# Epoch 64/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3805 - auc: 0.8942
# Epoch 65/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3797 - auc: 0.8941
# Epoch 66/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3795 - auc: 0.8939
# Epoch 67/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3803 - auc: 0.8935
# Epoch 68/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3783 - auc: 0.8947
# Epoch 69/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3784 - auc: 0.8951
# Epoch 70/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3773 - auc: 0.8955
# Epoch 71/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3778 - auc: 0.8949
# Epoch 72/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3766 - auc: 0.8953
# Epoch 73/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3769 - auc: 0.8950
# Epoch 74/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3755 - auc: 0.8965
# Epoch 75/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3752 - auc: 0.8961
# Epoch 76/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3748 - auc: 0.8963
# Epoch 77/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3753 - auc: 0.8959
# Epoch 78/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3745 - auc: 0.8962
# Epoch 79/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3739 - auc: 0.8966
# Epoch 80/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3727 - auc: 0.8968
# Epoch 81/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3726 - auc: 0.8973
# Epoch 82/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3729 - auc: 0.8963
# Epoch 83/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3720 - auc: 0.8967
# Epoch 84/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3719 - auc: 0.8967
# Epoch 85/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3719 - auc: 0.8973
# Epoch 86/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3707 - auc: 0.8975
# Epoch 87/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3706 - auc: 0.8976
# Epoch 88/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3709 - auc: 0.8979
# Epoch 89/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3697 - auc: 0.8982
# Epoch 90/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3696 - auc: 0.8979
# Epoch 91/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3694 - auc: 0.8981
# Epoch 92/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3689 - auc: 0.8984
# Epoch 93/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3687 - auc: 0.8979
# Epoch 94/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3677 - auc: 0.8988
# Epoch 95/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3680 - auc: 0.8984
# Epoch 96/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3671 - auc: 0.8988
# Epoch 97/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3671 - auc: 0.8995
# Epoch 98/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3674 - auc: 0.8988
# Epoch 99/100
# 19/19 [==============================] - 0s 3ms/step - loss: 0.3667 - auc: 0.8986
# Epoch 100/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3663 - auc: 0.8988

# %%
y_pred = model.predict(X_test)
# Out:
# 10/10 [==============================] - 0s 2ms/step

# %%
from sklearn.metrics import accuracy_score
a = accuracy_score(y_pred > 0.5,Y_test)
print('Accuracy is:', a*100)
# Out:
# Accuracy is: 81.69491525423729

# %%
#De esta forma graficamos la curva ROC y calculamos el área debajo de la curva
plt.figure(figsize=(10,10))
plt.title("Grafico ROC para el model")


areaBajoCurva = roc_auc_score(Y_test, y_pred)
fpr, tpr, _ = roc_curve(Y_test, y_pred)
plt.plot(fpr, tpr, label="{} - AUC:{}".format("red", round(areaBajoCurva,4)))


plt.legend(loc="lower right")
plt.plot([0,1])
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.show()

# %%
history = model.fit(X_train, Y_train,validation_data = (X_test,Y_test), epochs=100)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 1s 30ms/step - loss: 0.3658 - auc: 0.8997 - val_loss: 0.4367 - val_auc: 0.8596
# Epoch 2/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3654 - auc: 0.8998 - val_loss: 0.4368 - val_auc: 0.8588
# Epoch 3/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.3659 - auc: 0.8994 - val_loss: 0.4376 - val_auc: 0.8581
# Epoch 4/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3649 - auc: 0.8994 - val_loss: 0.4368 - val_auc: 0.8600
# Epoch 5/100
# 19/19 [==============================] - 0s 10ms/step - loss: 0.3648 - auc: 0.8998 - val_loss: 0.4377 - val_auc: 0.8594
# Epoch 6/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3661 - auc: 0.8987 - val_loss: 0.4375 - val_auc: 0.8586
# Epoch 7/100
# 19/19 [==============================] - 0s 11ms/step - loss: 0.3641 - auc: 0.9000 - val_loss: 0.4396 - val_auc: 0.8601
# Epoch 8/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.3640 - auc: 0.9003 - val_loss: 0.4381 - val_auc: 0.8588
# Epoch 9/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3637 - auc: 0.8999 - val_loss: 0.4386 - val_auc: 0.8592
# Epoch 10/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3627 - auc: 0.9008 - val_loss: 0.4390 - val_auc: 0.8585
# Epoch 11/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3629 - auc: 0.9006 - val_loss: 0.4386 - val_auc: 0.8598
# Epoch 12/100
# 19/19 [==============================] - 0s 10ms/step - loss: 0.3635 - auc: 0.9001 - val_loss: 0.4390 - val_auc: 0.8586
# Epoch 13/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.3623 - auc: 0.9011 - val_loss: 0.4382 - val_auc: 0.8588
# Epoch 14/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3626 - auc: 0.9006 - val_loss: 0.4403 - val_auc: 0.8582
# Epoch 15/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3620 - auc: 0.9011 - val_loss: 0.4394 - val_auc: 0.8582
# Epoch 16/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3612 - auc: 0.9011 - val_loss: 0.4389 - val_auc: 0.8583
# Epoch 17/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3609 - auc: 0.9019 - val_loss: 0.4393 - val_auc: 0.8589
# Epoch 18/100
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3608 - auc: 0.9014 - val_loss: 0.4398 - val_auc: 0.8585
# Epoch 19/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3605 - auc: 0.9017 - val_loss: 0.4405 - val_auc: 0.8581
# Epoch 20/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3602 - auc: 0.9023 - val_loss: 0.4408 - val_auc: 0.8579
# Epoch 21/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3600 - auc: 0.9020 - val_loss: 0.4397 - val_auc: 0.8581
# Epoch 22/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.3596 - auc: 0.9019 - val_loss: 0.4401 - val_auc: 0.8584
# Epoch 23/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.3595 - auc: 0.9021 - val_loss: 0.4416 - val_auc: 0.8583
# Epoch 24/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3615 - auc: 0.9017 - val_loss: 0.4431 - val_auc: 0.8581
# Epoch 25/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3588 - auc: 0.9016 - val_loss: 0.4398 - val_auc: 0.8578
# Epoch 26/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3592 - auc: 0.9021 - val_loss: 0.4406 - val_auc: 0.8575
# Epoch 27/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3586 - auc: 0.9019 - val_loss: 0.4423 - val_auc: 0.8582
# Epoch 28/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3579 - auc: 0.9023 - val_loss: 0.4410 - val_auc: 0.8588
# Epoch 29/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3584 - auc: 0.9027 - val_loss: 0.4416 - val_auc: 0.8584
# Epoch 30/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3576 - auc: 0.9034 - val_loss: 0.4416 - val_auc: 0.8586
# Epoch 31/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3574 - auc: 0.9028 - val_loss: 0.4412 - val_auc: 0.8589
# Epoch 32/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3572 - auc: 0.9029 - val_loss: 0.4424 - val_auc: 0.8578
# Epoch 33/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3568 - auc: 0.9028 - val_loss: 0.4410 - val_auc: 0.8575
# Epoch 34/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3573 - auc: 0.9028 - val_loss: 0.4419 - val_auc: 0.8581
# Epoch 35/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3568 - auc: 0.9021 - val_loss: 0.4437 - val_auc: 0.8579
# Epoch 36/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3562 - auc: 0.9029 - val_loss: 0.4415 - val_auc: 0.8575
# Epoch 37/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3562 - auc: 0.9033 - val_loss: 0.4417 - val_auc: 0.8585
# Epoch 38/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3562 - auc: 0.9035 - val_loss: 0.4422 - val_auc: 0.8585
# Epoch 39/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3553 - auc: 0.9031 - val_loss: 0.4424 - val_auc: 0.8596
# Epoch 40/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3551 - auc: 0.9032 - val_loss: 0.4431 - val_auc: 0.8581
# Epoch 41/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3556 - auc: 0.9035 - val_loss: 0.4416 - val_auc: 0.8574
# Epoch 42/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3552 - auc: 0.9033 - val_loss: 0.4428 - val_auc: 0.8596
# Epoch 43/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3543 - auc: 0.9040 - val_loss: 0.4417 - val_auc: 0.8587
# Epoch 44/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3546 - auc: 0.9036 - val_loss: 0.4422 - val_auc: 0.8594
# Epoch 45/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3550 - auc: 0.9042 - val_loss: 0.4453 - val_auc: 0.8578
# Epoch 46/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3543 - auc: 0.9043 - val_loss: 0.4431 - val_auc: 0.8598
# Epoch 47/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3538 - auc: 0.9041 - val_loss: 0.4419 - val_auc: 0.8588
# Epoch 48/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3532 - auc: 0.9040 - val_loss: 0.4450 - val_auc: 0.8596
# Epoch 49/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3535 - auc: 0.9052 - val_loss: 0.4436 - val_auc: 0.8593
# Epoch 50/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3527 - auc: 0.9048 - val_loss: 0.4426 - val_auc: 0.8591
# Epoch 51/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3532 - auc: 0.9041 - val_loss: 0.4423 - val_auc: 0.8579
# Epoch 52/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3525 - auc: 0.9044 - val_loss: 0.4422 - val_auc: 0.8585
# Epoch 53/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3520 - auc: 0.9049 - val_loss: 0.4435 - val_auc: 0.8591
# Epoch 54/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3515 - auc: 0.9051 - val_loss: 0.4442 - val_auc: 0.8590
# Epoch 55/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3519 - auc: 0.9049 - val_loss: 0.4444 - val_auc: 0.8582
# Epoch 56/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3512 - auc: 0.9058 - val_loss: 0.4445 - val_auc: 0.8583
# Epoch 57/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3508 - auc: 0.9060 - val_loss: 0.4446 - val_auc: 0.8581
# Epoch 58/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3513 - auc: 0.9051 - val_loss: 0.4433 - val_auc: 0.8582
# Epoch 59/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3523 - auc: 0.9050 - val_loss: 0.4456 - val_auc: 0.8574
# Epoch 60/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3497 - auc: 0.9063 - val_loss: 0.4426 - val_auc: 0.8584
# Epoch 61/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3498 - auc: 0.9068 - val_loss: 0.4453 - val_auc: 0.8584
# Epoch 62/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3493 - auc: 0.9062 - val_loss: 0.4459 - val_auc: 0.8577
# Epoch 63/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3494 - auc: 0.9064 - val_loss: 0.4436 - val_auc: 0.8577
# Epoch 64/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3489 - auc: 0.9071 - val_loss: 0.4452 - val_auc: 0.8574
# Epoch 65/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3490 - auc: 0.9069 - val_loss: 0.4456 - val_auc: 0.8583
# Epoch 66/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3483 - auc: 0.9066 - val_loss: 0.4467 - val_auc: 0.8590
# Epoch 67/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3479 - auc: 0.9072 - val_loss: 0.4462 - val_auc: 0.8577
# Epoch 68/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3483 - auc: 0.9070 - val_loss: 0.4463 - val_auc: 0.8580
# Epoch 69/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3481 - auc: 0.9069 - val_loss: 0.4465 - val_auc: 0.8595
# Epoch 70/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3474 - auc: 0.9072 - val_loss: 0.4447 - val_auc: 0.8577
# Epoch 71/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3476 - auc: 0.9079 - val_loss: 0.4448 - val_auc: 0.8579
# Epoch 72/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3479 - auc: 0.9069 - val_loss: 0.4454 - val_auc: 0.8586
# Epoch 73/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3465 - auc: 0.9085 - val_loss: 0.4461 - val_auc: 0.8577
# Epoch 74/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3467 - auc: 0.9082 - val_loss: 0.4477 - val_auc: 0.8587
# Epoch 75/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3459 - auc: 0.9088 - val_loss: 0.4465 - val_auc: 0.8585
# Epoch 76/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3469 - auc: 0.9075 - val_loss: 0.4462 - val_auc: 0.8595
# Epoch 77/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3461 - auc: 0.9088 - val_loss: 0.4490 - val_auc: 0.8573
# Epoch 78/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3478 - auc: 0.9061 - val_loss: 0.4479 - val_auc: 0.8580
# Epoch 79/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3452 - auc: 0.9088 - val_loss: 0.4483 - val_auc: 0.8583
# Epoch 80/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3453 - auc: 0.9088 - val_loss: 0.4458 - val_auc: 0.8586
# Epoch 81/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3453 - auc: 0.9083 - val_loss: 0.4475 - val_auc: 0.8585
# Epoch 82/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3448 - auc: 0.9088 - val_loss: 0.4491 - val_auc: 0.8574
# Epoch 83/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3446 - auc: 0.9091 - val_loss: 0.4475 - val_auc: 0.8576
# Epoch 84/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3446 - auc: 0.9090 - val_loss: 0.4467 - val_auc: 0.8581
# Epoch 85/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3440 - auc: 0.9085 - val_loss: 0.4488 - val_auc: 0.8579
# Epoch 86/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3437 - auc: 0.9092 - val_loss: 0.4481 - val_auc: 0.8581
# Epoch 87/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3433 - auc: 0.9093 - val_loss: 0.4482 - val_auc: 0.8575
# Epoch 88/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3444 - auc: 0.9080 - val_loss: 0.4487 - val_auc: 0.8577
# Epoch 89/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3429 - auc: 0.9091 - val_loss: 0.4495 - val_auc: 0.8581
# Epoch 90/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3433 - auc: 0.9092 - val_loss: 0.4488 - val_auc: 0.8575
# Epoch 91/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3433 - auc: 0.9094 - val_loss: 0.4477 - val_auc: 0.8580
# Epoch 92/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3432 - auc: 0.9094 - val_loss: 0.4500 - val_auc: 0.8575
# Epoch 93/100
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3436 - auc: 0.9093 - val_loss: 0.4502 - val_auc: 0.8575
# Epoch 94/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3420 - auc: 0.9098 - val_loss: 0.4498 - val_auc: 0.8578
# Epoch 95/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3426 - auc: 0.9085 - val_loss: 0.4493 - val_auc: 0.8576
# Epoch 96/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3420 - auc: 0.9099 - val_loss: 0.4484 - val_auc: 0.8575
# Epoch 97/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3415 - auc: 0.9106 - val_loss: 0.4520 - val_auc: 0.8571
# Epoch 98/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3408 - auc: 0.9097 - val_loss: 0.4501 - val_auc: 0.8582
# Epoch 99/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3410 - auc: 0.9102 - val_loss: 0.4505 - val_auc: 0.8586
# Epoch 100/100
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3410 - auc: 0.9099 - val_loss: 0.4506 - val_auc: 0.8581

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'auc', 'val_loss', 'val_auc'])

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss']) 
plt.plot(history.history['val_loss']) 
plt.title('Model loss') 
plt.ylabel('Loss') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper left') 
plt.show()
